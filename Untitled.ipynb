# %%
# widget
import pandas as pd
import matplotlib.pyplot as plt
# plt.style.use('ggplot')

# %%
# %matplotlib inline

# %%
data = pd.read_csv('pandas/group_data.csv', na_values='?')
data.sample(10)
# Out:
#       pclass  survived                                               name  \
# 1185       3         0                                  Samaan, Mr. Hanna
# 62         1         0                        Chaffee, Mr. Herbert Fuller
# 435        2         0                                 Hart, Mr. Benjamin
# 1139       3         0                                    Rekic, Mr. Tido
# 470        2         0                                  Keane, Mr. Daniel
# 785        3         1  Dyker, Mrs. Adolf Fredrik (Anna Elisabeth Judi...
# 596        2         1                              Wilhelms, Mr. Charles
# 1014       3         0            Meek, Mrs. Thomas (Annie Louise Rowley)
# 371        2         1                      Christy, Mrs. (Alice Frances)
# 504        2         0                                  Meyer, Mr. August
#
#          sex   age  sibsp  parch        ticket     fare cabin embarked boat  \
# 1185    male   NaN      2      0          2662  21.6792   NaN        C  NaN
# ...

# %%
g_data = data.groupby(['pclass'])
# g_data.sample(10)

# %%
# data[(data['survived'] == 1) & (data['sex'] == 'male')]
g_data['survived'].sum()
# Out:
# pclass
# 1    200
# 2    119
# 3    181
# Name: survived, dtype: int64

# %%
g_data['survived'].sum().plot(kind='bar')
plt.title("number of survivors by gander")
plt.ylabel("# survivors")
plt.show()

# %%
# ?plt.plot
# Out:
# Signature: plt.plot(*args, scalex=True, scaley=True, data=None, **kwargs)
# Docstring:
# Plot y versus x as lines and/or markers.
#
# Call signatures::
#
#     plot([x], y, [fmt], *, data=None, **kwargs)
#     plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
# The coordinates of the points or line nodes are given by *x*, *y*.
#
# The optional parameter *fmt* is a convenient way for defining basic
# formatting like color, marker and linestyle. It's a shortcut string
# notation described in the *Notes* section below.
#
# >>> plot(x, y)        # plot x and y using default line style and color
# >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
# >>> plot(y)           # plot y using x as index array 0..N-1
# >>> plot(y, 'r+')     # ditto, but with red plusses
#
# You can use `.Line2D` properties as keyword arguments for more
# control on the appearance. Line properties and *fmt* can be mixed.
# The following two calls yield identical results:
#
# ...

# %%
# %timeit data[data['name'] == 'Connors, Mr. Patrick']
# %timeit data.query("name == 'Connors, Mr. Patrick'") # too slow i don't recommend
# Out:
# 389 µs ± 10.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 1.37 ms ± 36.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
import math
from math import comb 
import itertools

# res = itertools.combinations_with_replacement([1,2,3,4,5,6,7],4)

c = math.comb(6,3)
a = (7*6*5*4)/7**4

comb(8,4) + comb(6,3) + comb(4,2) + comb(2,1) + 39
# Out:
# 137

# %%
7**4
# Out:
# 2401

# %%
https://iz7hz4.axshare.com/?code=5d4acca8b36532a05a8b1c26466368c3&id=tslqd1

# %%
from fpdf import FPDF

# Create a PDF class
class PDF(FPDF):
    def header(self):
        self.set_font("Arial", "B", 16)
        self.cell(0, 10, "Sample PDF Document", ln=True, align="C")

    def footer(self):
        self.set_y(-15)
        self.set_font("Arial", "I", 8)
        self.cell(0, 10, f"Page {self.page_no()}", align="C")

# Initialize PDF
pdf = PDF()
pdf.add_page()
pdf.set_font("Arial", size=12)

# Dummy content
dummy_text = (
    "Lorem ipsum dolor sit amet, consectetur adipiscing elit. "
    "Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. "
    "Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi "
    "ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit "
    "in voluptate velit esse cillum dolore eu fugiat nulla pariatur. "
    "Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia "
    "deserunt mollit anim id est laborum."
)

# Add content
pdf.multi_cell(0, 10, dummy_text)

# Save PDF to a file
pdf.output("sample_dummy_page.pdf")
# Out:
# ''

# %%
def helper(a,b):
    
    if a == 0 or b == 0:
        return 0
    
    return a +  helper(a,b - 1)


helper(9,2)
# Out:
# 18
